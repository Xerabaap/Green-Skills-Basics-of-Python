# %%
# Lambda function to check if a year is a leap year
is_leap_year = lambda year: (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

# Example usage
year = int(input("Enter a year: "))
print(f"{year} is a Leap Year." if is_leap_year(year) else f"{year} is not a Leap Year.")

# %%
projects_df = pd.DataFrames(data)
projects_df.head()

# %%
grouped_data = projects_df.groupby("Technology")//["Capacity (MW)"]
print("\ntotal Capacity by Technology")
print(grouped_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-70e54ea36cab> in <cell line: 1>()
# ----> 1 grouped_data = projects_df.groupby("Technology")//["Capacity (MW)"]
#       2 print("\ntotal Capacity by Technology")
#       3 print(grouped_data)
#
# NameError: name 'projects_df' is not defined

# %%
import numpy as np
two_d_array = np.array(([1,2],[3,4]))
print(two_d_array)
# Out:
# [[1 2]
#  [3 4]]

# %%
two_d_array.shape
two_d_array.ndim
# Out:
# 2

# %%
import numpy as np
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.zeros(1)
# Out:
# array([0.])

# %%
array1 = np.arange(0,10,2)
print(array1)
# Out:
# [0 2 4 6 8]

# %%
array1 = np.arange(0,10,2)
print(array1)

array2 = np.arange(5,15,2)
print(array2)
# Out:
# [0 2 4 6 8]
# [ 5  7  9 11 13]

# %%
linspace_array1 = np.linspace(5,10,3)
print(linspace_array1)
# Out:
# [ 5.   7.5 10. ]

# %%
num_data = np.array([11,22,33,44,55,66,77,88,99])
print(num_data[:])

print(num_data[::1])

print(num_data[::2])

print(num_data[::-1])
# Out:
# [11 22 33 44 55 66 77 88 99]
# [11 22 33 44 55 66 77 88 99]
# [11 33 55 77 99]
# [99 88 77 66 55 44 33 22 11]

# %%
num_data = np.array([[1,2,3], [4,5,6]])
reshaped_data = num_data.reshape(2,3)
print(reshaped_data)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import pandas as pd
data = {
    "Energy Source":["Solar", "Wind", "Hydropower", "Geothermal", "Biomas", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}

energy_df = pd.DataFrame(data)
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4        Biomas                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
forward_filled_df = energy_df.fillna(method="ffill")
print("\nData Before Forward Filling:")
print(energy_df)
print("\nData After Forward Filling:")
forward_filled_df.head()
# Out:
# Data Before Forward Filling:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4        Biomas                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
#
# Data After Forward Filling:
# <ipython-input-20-3dbef0dcd746>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_filled_df = energy_df.fillna(method="ffill")
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    1200.0             400.0
# 2    Hydropower                    2900.0             400.0
# ...

# %%
from sklearn.preprocessing import  MinMaxScalar

scaler = MinMaxScalar()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scalar.fir_transform(
    energy_df[["Energy Consumption (Mwh)" , "Cost (Million $)"]]
)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Creating a DataFrame for pair plot
data = {
"Solar": [1200, 1500, 1300],
"Wind": [3400, 3600, 3200],
"Hydropower": [2900, 3100, 2800],
"Blomass": [2500, 2700, 2400]
}

df =pd.DataFrame(data)
#a Ceate a pair plot
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show('Correaltion Between Energy Sources')
plt.show()

# %%
sns.boxplot(data=df)

plt.title("Dsitribution of Energy Consumption by Source")
plt.show()

# %%
sns.violinplot(data=df)
plt.title("Violin Plot of Energy Consumption Distribution")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

energy_values = [100, 200, 300, 400, 500]
carbon_emission = [10, 20, 30, 40, 50]

df_reg = pd.DataFrame(
    "Energy Consumption" : energy_values
    "Carbon Emission" : carbon_emission

)

sns.regplot(x="Energy Consumption", y="Carbon Emission", data=df_reg)

# %%
import numpy as np
from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')
z = np.linspace(0,1,1000)
x=z*np.sin(25*z)
y=z*np.cos(25*z)
ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/content/IRIS.csv")

# 1. Pair Plot
sns.pairplot(df)
plt.title('Pair Plot')
plt.show()

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.pairplot(df,hue = 'species',palette="husl",size=2)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
numerical_data = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_matrix = numerical_data.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlations')
plt.show()
